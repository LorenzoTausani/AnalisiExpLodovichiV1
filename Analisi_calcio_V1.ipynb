# %% [markdown]
# https://suite2p.readthedocs.io/en/latest/outputs.html

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import mode
import os
import glob
import re
import copy

plt.rcParams.update({
    'font.size': 14,
    'lines.linewidth': 2,
    'figure.figsize': [15, 6]
})

def get_dbn_library(files,repository_url):
  for file in files:
    ! wget -O {file} {repository_url}{file}


get_dbn_library(files = ["Plotting_functions.py","Utils.py"], repository_url = "https://raw.githubusercontent.com/LorenzoTausani/AnalisiExpLodovichiV1/master/")

import Plotting_functions
import Utils
from Plotting_functions import *
from Utils import *

#Analyze_all(Force_reanalysis = True) #commenta se non vuoi rianalizzare/analizzare le sessioni
#return_dict= single_session_analysis()
# Out:
# --2023-05-19 13:32:38--  https://raw.githubusercontent.com/LorenzoTausani/AnalisiExpLodovichiV1/master/Plotting_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10313 (10K) [text/plain]
# Saving to: ‘Plotting_functions.py’
#
# Plotting_functions. 100%[===================>]  10.07K  --.-KB/s    in 0s
#
# 2023-05-19 13:32:38 (78.6 MB/s) - ‘Plotting_functions.py’ saved [10313/10313]
#
# --2023-05-19 13:32:38--  https://raw.githubusercontent.com/LorenzoTausani/AnalisiExpLodovichiV1/master/Utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
return_dict= single_session_analysis()
# Out:
# Mounted at /content/drive
# Which subject?
# 0: 714_23
# 1: 716_230
# Which session?
# 0: 20230427_714_Spre6
# 1: 20230427_714_Spost10
# 2: 20230427_714_Spre8
# 3: 20230427_714_Spre52
# /content/Utils.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Orientamenti'][it] = 'gray '+str(orientamento)
# /content/Utils.py:326: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   cell_OSI_dict['PrefOr'] = np.array(PrefOr_v)
